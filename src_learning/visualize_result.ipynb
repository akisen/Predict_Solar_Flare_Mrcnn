# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
loss_df = pd.read_csv('/home/akito/GoogleDrive/Lab/Presentation/20210112中間発表/Sun1126T0622/loss.csv')
val_loss_df = pd.read_csv('/home/akito/GoogleDrive/Lab/Presentation/20210112中間発表/Sun1126T0622/val_loss.csv')

# %%
loss_df.iloc[:,2]
# Out:
# 0      2.584746
# 1      1.723655
# 2      1.571902
# 3      1.502314
# 4      1.369979
#          ...
# 155    0.461717
# 156    0.471216
# 157    0.435776
# 158    0.472234
# 159    0.466129
# Name: Value, Length: 160, dtype: float64

# %%
x =np.arange(0,167,1)
ax = plt.figure()
plt.plot(x,loss_df.iloc[:,2],c="blue",label="loss")
plt.plot(x,val_loss_df.iloc[:,2],c="orange",label="val_loss")
plt.xlabel("epoch",fontsize=20)
plt.ylabel("loss",fontsize=20)
plt.ylim(0,2.5)
plt.legend()
plt.savefig("losses.png")
